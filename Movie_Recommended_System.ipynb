# %% [markdown]
# <a href="https://colab.research.google.com/github/sagnik765/Movie-Recommended-System/blob/main/Movie_Recommended_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
movie = pd.read_csv('/content/movies_metadata.csv')

# %%
movie.head()
# Out:
#    adult  ... vote_count
# 0  False  ...     5415.0
# 1  False  ...     2413.0
# 2  False  ...       92.0
# 3  False  ...       34.0
# 4  False  ...      173.0
#
# [5 rows x 24 columns]

# %%
for i in movie.columns:
    print(i)
# Out:
# adult
# belongs_to_collection
# budget
# genres
# homepage
# id
# imdb_id
# original_language
# original_title
# overview
# popularity
# poster_path
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# video
# vote_average
# vote_count

# %%
movie.shape
# Out:
# (28070, 24)

# %%
movie.describe()
# Out:
#          popularity       revenue       runtime  vote_average    vote_count
# count  28068.000000  2.806700e+04  28008.000000  28067.000000  28067.000000
# mean       3.638354  1.589339e+07     98.053949      5.823398    151.572844
# std        5.457443  7.504095e+07     34.241464      1.677031    584.592748
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%        0.587848  0.000000e+00     88.000000      5.300000      5.000000
# 50%        1.699885  0.000000e+00     97.000000      6.100000     15.000000
# 75%        5.526636  0.000000e+00    109.000000      6.800000     58.000000
# max      213.849907  2.787965e+09   1256.000000     10.000000  14075.000000

# %%
movie['original_language'].value_counts()
# Out:
# en       21547
# fr        1489
# ja         802
# it         603
# de         551
#          ...
# eo           1
# fy           1
# ne           1
# 104.0        1
# cy           1
# Name: original_language, Length: 80, dtype: int64

# %%
movie['original_language'].value_counts()[0:5]
# Out:
# en    21547
# fr     1489
# ja      802
# it      603
# de      551
# Name: original_language, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(movie['original_language'].value_counts()[0:5].keys()),list(movie['original_language'].value_counts()[0:5]),color="r")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(movie['vote_average'])
plt.show()

# %%
high_rated_movies=movie[movie['vote_average']>8]

# %%
high_rated_movies.head()
# Out:
#      adult  ... vote_count
# 46   False  ...     5915.0
# 49   False  ...     3334.0
# 109  False  ...     2632.0
# 186  False  ...        1.0
# 256  False  ...     6778.0
#
# [5 rows x 24 columns]

# %%
high_rated_movies.shape
# Out:
# (528, 24)

# %%
top5_high=high_rated_movies.sort_values(by="vote_average",ascending=False).head()

# %%
top5_high
# Out:
#        adult belongs_to_collection budget  ...  video vote_average vote_count
# 24733  False                   NaN      0  ...  False         10.0        1.0
# 25654  False                   NaN      0  ...  False         10.0        1.0
# 2948   False                   NaN      0  ...  False         10.0        1.0
# 16687  False                   NaN      0  ...  False         10.0        1.0
# 25748  False                   NaN      0  ...  False         10.0        1.0
#
# [5 rows x 24 columns]

# %%
top5_revenue=movie.sort_values(by="revenue",ascending=False).head()

# %%
top5_revenue
# Out:
#        adult  ... vote_count
# 14551  False  ...    12114.0
# 26555  False  ...     7993.0
# 1639   False  ...     7770.0
# 17818  False  ...    12000.0
# 25084  False  ...     8842.0
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(5,5))
plt.hist(movie['runtime'])
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(movie['vote_count'])
plt.show()

# %%
movie['status'].value_counts()
# Out:
# Released           27881
# Rumored              124
# Post Production       20
# In Production          4
# Planned                2
# Name: status, dtype: int64
